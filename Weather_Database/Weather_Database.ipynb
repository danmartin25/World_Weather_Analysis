# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import requests library
import requests

# Import API key
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | alofi
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | sao filipe
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | hobyo
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | mamallapuram
# Processing Record 11 of Set 1 | oktyabrskoye
# Processing Record 12 of Set 1 | spearfish
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | kassala
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | waipawa
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | huarmey
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | villa bruzual
# Processing Record 22 of Set 1 | ouadda
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | grand gaube
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | san patricio
# Processing Record 27 of Set 1 | margate
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | tateyama
# Processing Record 31 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | hammerfest
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | purbalingga
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | oktyabrskiy
# Processing Record 43 of Set 1 | farafangana
# Processing Record 44 of Set 1 | ardahan
# Processing Record 45 of Set 1 | beruwala
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | gomel
# Processing Record 48 of Set 1 | kropotkin
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | vila franca do campo
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | kandy
# Processing Record 4 of Set 2 | uzunovo
# Processing Record 5 of Set 2 | hofn
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | mogadishu
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | sakakah
# Processing Record 17 of Set 2 | sunndalsora
# Processing Record 18 of Set 2 | saint-francois
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | caravelas
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | ovalle
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | yurya
# City not found. Skipping...
# Processing Record 26 of Set 2 | jumla
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | flinders
# Processing Record 30 of Set 2 | belmonte
# Processing Record 31 of Set 2 | guicheng
# City not found. Skipping...
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | el sauzal
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | nouadhibou
# Processing Record 37 of Set 2 | nabire
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | valpacos
# Processing Record 40 of Set 2 | aitape
# Processing Record 41 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | fort nelson
# Processing Record 46 of Set 2 | wuda
# Processing Record 47 of Set 2 | urucurituba
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | ginda
# Processing Record 50 of Set 2 | luwuk
# Processing Record 1 of Set 3 | meulaboh
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | lethem
# Processing Record 5 of Set 3 | vao
# Processing Record 6 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 3 | vestmanna
# Processing Record 8 of Set 3 | polis
# Processing Record 9 of Set 3 | ucluelet
# Processing Record 10 of Set 3 | aguililla
# Processing Record 11 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | fenoarivo
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | tabou
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | lasa
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 3 | monroe
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | yerbogachen
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | puebla
# Processing Record 29 of Set 3 | puerto ayora
# Processing Record 30 of Set 3 | gusau
# Processing Record 31 of Set 3 | zhangye
# Processing Record 32 of Set 3 | petrovskoye
# Processing Record 33 of Set 3 | bilma
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | kamenka
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | kutum
# Processing Record 41 of Set 3 | kabanjahe
# Processing Record 42 of Set 3 | maryborough
# Processing Record 43 of Set 3 | cooma
# Processing Record 44 of Set 3 | kampot
# Processing Record 45 of Set 3 | muli
# Processing Record 46 of Set 3 | bantry
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | isangel
# Processing Record 49 of Set 3 | cabedelo
# Processing Record 50 of Set 3 | verkhnevilyuysk
# Processing Record 1 of Set 4 | jinji
# Processing Record 2 of Set 4 | atasu
# Processing Record 3 of Set 4 | ho
# City not found. Skipping...
# Processing Record 4 of Set 4 | egvekinot
# Processing Record 5 of Set 4 | mecca
# Processing Record 6 of Set 4 | nelson bay
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | sogdiondon
# City not found. Skipping...
# Processing Record 9 of Set 4 | yarim
# Processing Record 10 of Set 4 | bumba
# Processing Record 11 of Set 4 | sao benedito do rio preto
# Processing Record 12 of Set 4 | tura
# Processing Record 13 of Set 4 | anadyr
# Processing Record 14 of Set 4 | gondar
# Processing Record 15 of Set 4 | saskylakh
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | panguna
# Processing Record 18 of Set 4 | nanlong
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | pacific grove
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | dzhebariki-khaya
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | kirovsk
# Processing Record 27 of Set 4 | maragogi
# Processing Record 28 of Set 4 | northam
# Processing Record 29 of Set 4 | plaridel
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | dutlwe
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | douglas
# Processing Record 34 of Set 4 | kitimat
# Processing Record 35 of Set 4 | msanga
# Processing Record 36 of Set 4 | aquiraz
# Processing Record 37 of Set 4 | collierville
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | nome
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | lebu
# Processing Record 42 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 4 | portoferraio
# Processing Record 44 of Set 4 | yakima
# Processing Record 45 of Set 4 | hovd
# Processing Record 46 of Set 4 | amboise
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | teofilo otoni
# Processing Record 49 of Set 4 | leh
# Processing Record 50 of Set 4 | beringovskiy
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | asilah
# Processing Record 3 of Set 5 | sorland
# Processing Record 4 of Set 5 | bredasdorp
# Processing Record 5 of Set 5 | biak
# Processing Record 6 of Set 5 | sombrio
# Processing Record 7 of Set 5 | barrow
# Processing Record 8 of Set 5 | kizukuri
# Processing Record 9 of Set 5 | freeport
# Processing Record 10 of Set 5 | byron bay
# Processing Record 11 of Set 5 | lorengau
# Processing Record 12 of Set 5 | santa flavia
# Processing Record 13 of Set 5 | usak
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | virginia beach
# Processing Record 16 of Set 5 | riberalta
# Processing Record 17 of Set 5 | cascais
# Processing Record 18 of Set 5 | deputatskiy
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | waingapu
# Processing Record 21 of Set 5 | ribeira grande
# Processing Record 22 of Set 5 | chengde
# Processing Record 23 of Set 5 | barillas
# Processing Record 24 of Set 5 | aksay
# Processing Record 25 of Set 5 | pinheiro
# Processing Record 26 of Set 5 | dikson
# Processing Record 27 of Set 5 | khandbari
# Processing Record 28 of Set 5 | saldanha
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | fare
# Processing Record 31 of Set 5 | komsomolskiy
# Processing Record 32 of Set 5 | tilichiki
# Processing Record 33 of Set 5 | swan river
# Processing Record 34 of Set 5 | purpe
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | dryden
# Processing Record 38 of Set 5 | astorga
# Processing Record 39 of Set 5 | harer
# Processing Record 40 of Set 5 | namatanai
# Processing Record 41 of Set 5 | uyuni
# Processing Record 42 of Set 5 | neepawa
# Processing Record 43 of Set 5 | pagudpud
# Processing Record 44 of Set 5 | turbiv
# Processing Record 45 of Set 5 | mitu
# Processing Record 46 of Set 5 | shingu
# Processing Record 47 of Set 5 | edd
# Processing Record 48 of Set 5 | lagoa
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | eureka
# Processing Record 1 of Set 6 | monrovia
# Processing Record 2 of Set 6 | hohhot
# Processing Record 3 of Set 6 | quatre cocos
# Processing Record 4 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 6 | severo-kurilsk
# Processing Record 6 of Set 6 | mpanda
# Processing Record 7 of Set 6 | unai
# Processing Record 8 of Set 6 | saint-joseph
# Processing Record 9 of Set 6 | meybod
# Processing Record 10 of Set 6 | puerto montt
# Processing Record 11 of Set 6 | wanning
# Processing Record 12 of Set 6 | ocos
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | umtata
# Processing Record 15 of Set 6 | faya
# Processing Record 16 of Set 6 | samoded
# Processing Record 17 of Set 6 | mana
# Processing Record 18 of Set 6 | lure
# Processing Record 19 of Set 6 | zdvinsk
# Processing Record 20 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 6 | himora
# City not found. Skipping...
# Processing Record 22 of Set 6 | smithers
# Processing Record 23 of Set 6 | dakar
# Processing Record 24 of Set 6 | loa janan
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | mount gambier
# Processing Record 28 of Set 6 | labuhan
# Processing Record 29 of Set 6 | soyo
# Processing Record 30 of Set 6 | asau
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | tromso
# Processing Record 33 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | faanui
# Processing Record 36 of Set 6 | kidal
# Processing Record 37 of Set 6 | ayan
# Processing Record 38 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 6 | maceio
# Processing Record 40 of Set 6 | sande
# Processing Record 41 of Set 6 | tucuman
# Processing Record 42 of Set 6 | santa cruz de tenerife
# Processing Record 43 of Set 6 | balkhash
# Processing Record 44 of Set 6 | inuvik
# Processing Record 45 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 46 of Set 6 | half moon bay
# Processing Record 47 of Set 6 | carutapera
# Processing Record 48 of Set 6 | belogorsk
# Processing Record 49 of Set 6 | rio grande
# Processing Record 50 of Set 6 | semey
# Processing Record 1 of Set 7 | hermiston
# Processing Record 2 of Set 7 | ahuimanu
# Processing Record 3 of Set 7 | yumen
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | bethel
# Processing Record 6 of Set 7 | kemijarvi
# Processing Record 7 of Set 7 | namwala
# Processing Record 8 of Set 7 | siderno
# Processing Record 9 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | iqaluit
# Processing Record 11 of Set 7 | mitsamiouli
# Processing Record 12 of Set 7 | burica
# City not found. Skipping...
# Processing Record 13 of Set 7 | bastia
# Processing Record 14 of Set 7 | lukovetskiy
# Processing Record 15 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 7 | montepuez
# Processing Record 17 of Set 7 | chara
# Processing Record 18 of Set 7 | port augusta
# Processing Record 19 of Set 7 | norman wells
# Processing Record 20 of Set 7 | beidao
# Processing Record 21 of Set 7 | giresun
# Processing Record 22 of Set 7 | betma
# Processing Record 23 of Set 7 | teya
# Processing Record 24 of Set 7 | davila
# Processing Record 25 of Set 7 | mme
# City not found. Skipping...
# Processing Record 26 of Set 7 | payo
# Processing Record 27 of Set 7 | pangnirtung
# Processing Record 28 of Set 7 | liverpool
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | warrington
# Processing Record 31 of Set 7 | beloha
# Processing Record 32 of Set 7 | nueva italia
# Processing Record 33 of Set 7 | kumbo
# Processing Record 34 of Set 7 | san jose de guanipa
# Processing Record 35 of Set 7 | gamba
# Processing Record 36 of Set 7 | ambon
# Processing Record 37 of Set 7 | viedma
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | decin
# Processing Record 40 of Set 7 | havre-saint-pierre
# Processing Record 41 of Set 7 | chimbote
# Processing Record 42 of Set 7 | odweyne
# Processing Record 43 of Set 7 | kumylzhenskaya
# Processing Record 44 of Set 7 | sinnamary
# Processing Record 45 of Set 7 | rawson
# Processing Record 46 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 47 of Set 7 | katherine
# Processing Record 48 of Set 7 | umm lajj
# Processing Record 49 of Set 7 | seoul
# Processing Record 50 of Set 7 | bapatla
# Processing Record 1 of Set 8 | souillac
# Processing Record 2 of Set 8 | shache
# Processing Record 3 of Set 8 | atambua
# Processing Record 4 of Set 8 | puerto escondido
# Processing Record 5 of Set 8 | mastung
# Processing Record 6 of Set 8 | batagay
# Processing Record 7 of Set 8 | torbay
# Processing Record 8 of Set 8 | lata
# Processing Record 9 of Set 8 | ramos arizpe
# Processing Record 10 of Set 8 | buraydah
# Processing Record 11 of Set 8 | le port
# Processing Record 12 of Set 8 | sisimiut
# Processing Record 13 of Set 8 | nagar karnul
# Processing Record 14 of Set 8 | shirpur
# Processing Record 15 of Set 8 | raga
# Processing Record 16 of Set 8 | nishihara
# Processing Record 17 of Set 8 | boyolangu
# Processing Record 18 of Set 8 | salalah
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | kedougou
# Processing Record 21 of Set 8 | chissamba
# Processing Record 22 of Set 8 | longyearbyen
# Processing Record 23 of Set 8 | tommot
# Processing Record 24 of Set 8 | aksha
# Processing Record 25 of Set 8 | husavik
# Processing Record 26 of Set 8 | port dover
# Processing Record 27 of Set 8 | luganville
# Processing Record 28 of Set 8 | kimbe
# Processing Record 29 of Set 8 | komyshuvakha
# Processing Record 30 of Set 8 | korla
# Processing Record 31 of Set 8 | dunedin
# Processing Record 32 of Set 8 | amapa
# Processing Record 33 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 8 | la ronge
# Processing Record 35 of Set 8 | sao jose de ribamar
# Processing Record 36 of Set 8 | portland
# Processing Record 37 of Set 8 | robertsport
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | murmansk
# Processing Record 40 of Set 8 | khatanga
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | romitan
# Processing Record 43 of Set 8 | sergeyevka
# Processing Record 44 of Set 8 | road town
# Processing Record 45 of Set 8 | cidreira
# Processing Record 46 of Set 8 | kenai
# Processing Record 47 of Set 8 | pandan
# Processing Record 48 of Set 8 | port hedland
# Processing Record 49 of Set 8 | touros
# Processing Record 50 of Set 8 | flagstaff
# Processing Record 1 of Set 9 | santiago del estero
# Processing Record 2 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 9 | san juan de flores
# Processing Record 4 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 9 | zarubino
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | santa marta
# Processing Record 8 of Set 9 | veere
# Processing Record 9 of Set 9 | te anau
# Processing Record 10 of Set 9 | umba
# Processing Record 11 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 12 of Set 9 | madang
# Processing Record 13 of Set 9 | port hardy
# Processing Record 14 of Set 9 | estevan
# Processing Record 15 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 9 | sept-iles
# Processing Record 17 of Set 9 | la palma
# Processing Record 18 of Set 9 | lompoc
# Processing Record 19 of Set 9 | ust-tsilma
# Processing Record 20 of Set 9 | voiron
# Processing Record 21 of Set 9 | opuwo
# Processing Record 22 of Set 9 | ostuni
# Processing Record 23 of Set 9 | kajaani
# Processing Record 24 of Set 9 | tequila
# Processing Record 25 of Set 9 | los llanos de aridane
# Processing Record 26 of Set 9 | ihosy
# Processing Record 27 of Set 9 | chernigovka
# Processing Record 28 of Set 9 | astoria
# Processing Record 29 of Set 9 | kodinsk
# Processing Record 30 of Set 9 | kattivakkam
# Processing Record 31 of Set 9 | laibin
# Processing Record 32 of Set 9 | olafsvik
# Processing Record 33 of Set 9 | poum
# Processing Record 34 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 9 | svay rieng
# Processing Record 36 of Set 9 | nago
# Processing Record 37 of Set 9 | peringat
# Processing Record 38 of Set 9 | ardatov
# Processing Record 39 of Set 9 | ardesen
# Processing Record 40 of Set 9 | dali
# Processing Record 41 of Set 9 | teguise
# Processing Record 42 of Set 9 | vestmannaeyjar
# Processing Record 43 of Set 9 | karema
# Processing Record 44 of Set 9 | asyut
# Processing Record 45 of Set 9 | luba
# Processing Record 46 of Set 9 | pahrump
# Processing Record 47 of Set 9 | reefton
# City not found. Skipping...
# Processing Record 48 of Set 9 | hopatcong
# Processing Record 49 of Set 9 | springfield
# Processing Record 50 of Set 9 | cochrane
# Processing Record 1 of Set 10 | mayo
# Processing Record 2 of Set 10 | fukue
# Processing Record 3 of Set 10 | povolzhskiy
# Processing Record 4 of Set 10 | vardo
# Processing Record 5 of Set 10 | adelaide
# Processing Record 6 of Set 10 | skibbereen
# Processing Record 7 of Set 10 | tikapur
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | vanavara
# Processing Record 10 of Set 10 | mihai bravu
# Processing Record 11 of Set 10 | guzelyurt
# Processing Record 12 of Set 10 | cap malheureux
# Processing Record 13 of Set 10 | saint-georges
# Processing Record 14 of Set 10 | santa fe
# Processing Record 15 of Set 10 | tocopilla
# Processing Record 16 of Set 10 | itanhaem
# Processing Record 17 of Set 10 | sengiley
# Processing Record 18 of Set 10 | proletarsk
# Processing Record 19 of Set 10 | aksu
# Processing Record 20 of Set 10 | santa rosa
# Processing Record 21 of Set 10 | bahia blanca
# Processing Record 22 of Set 10 | hargeysa
# Processing Record 23 of Set 10 | dwarka
# Processing Record 24 of Set 10 | omboue
# Processing Record 25 of Set 10 | bambous virieux
# Processing Record 26 of Set 10 | lidkoping
# Processing Record 27 of Set 10 | champasak
# Processing Record 28 of Set 10 | babol
# Processing Record 29 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 10 | keetmanshoop
# Processing Record 31 of Set 10 | karlshamn
# Processing Record 32 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 10 | luderitz
# Processing Record 34 of Set 10 | airai
# Processing Record 35 of Set 10 | manjacaze
# Processing Record 36 of Set 10 | basoko
# Processing Record 37 of Set 10 | shimoda
# Processing Record 38 of Set 10 | victor harbor
# Processing Record 39 of Set 10 | haljala
# Processing Record 40 of Set 10 | avera
# Processing Record 41 of Set 10 | tatawin
# Processing Record 42 of Set 10 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 43 of Set 10 | pasni
# Processing Record 44 of Set 10 | hof
# Processing Record 45 of Set 10 | el cope
# Processing Record 46 of Set 10 | thinadhoo
# Processing Record 47 of Set 10 | milkovo
# Processing Record 48 of Set 10 | jabinyanah
# Processing Record 49 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 50 of Set 10 | paris
# Processing Record 1 of Set 11 | bambanglipuro
# Processing Record 2 of Set 11 | sterling
# Processing Record 3 of Set 11 | ulagan
# Processing Record 4 of Set 11 | gisborne
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | chicama
# Processing Record 7 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 11 | killybegs
# Processing Record 10 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 11 | chacabuco
# Processing Record 12 of Set 11 | taboshar
# Processing Record 13 of Set 11 | sehithwa
# Processing Record 14 of Set 11 | sandnessjoen
# Processing Record 15 of Set 11 | goderich
# Processing Record 16 of Set 11 | guerrero negro
# Processing Record 17 of Set 11 | nadym
# Processing Record 18 of Set 11 | palora
# Processing Record 19 of Set 11 | mount isa
# Processing Record 20 of Set 11 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 21 of Set 11 | kaduy
# Processing Record 22 of Set 11 | yinchuan
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | bardiyah
# Processing Record 25 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 11 | wanaka
# Processing Record 27 of Set 11 | sambava
# Processing Record 28 of Set 11 | guilin
# Processing Record 29 of Set 11 | kupang
# Processing Record 30 of Set 11 | morro bay
# Processing Record 31 of Set 11 | varnavino
# Processing Record 32 of Set 11 | fredericton
# Processing Record 33 of Set 11 | poya
# Processing Record 34 of Set 11 | griffith
# Processing Record 35 of Set 11 | chama
# Processing Record 36 of Set 11 | atar
# Processing Record 37 of Set 11 | sturlic
# Processing Record 38 of Set 11 | kabinda
# Processing Record 39 of Set 11 | tari
# Processing Record 40 of Set 11 | manzhouli
# Processing Record 41 of Set 11 | hurghada
# Processing Record 42 of Set 11 | tessalit
# Processing Record 43 of Set 11 | grand-santi
# Processing Record 44 of Set 11 | leningradskiy
# Processing Record 45 of Set 11 | pundaguitan
# Processing Record 46 of Set 11 | delijan
# Processing Record 47 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 11 | bud
# Processing Record 50 of Set 11 | tautira
# Processing Record 1 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 12 | zeya
# Processing Record 3 of Set 12 | anchorage
# Processing Record 4 of Set 12 | yulara
# Processing Record 5 of Set 12 | catamarca
# Processing Record 6 of Set 12 | surab
# Processing Record 7 of Set 12 | coquimbo
# Processing Record 8 of Set 12 | igboho
# Processing Record 9 of Set 12 | nantucket
# Processing Record 10 of Set 12 | derzhavinsk
# Processing Record 11 of Set 12 | nagornyy
# Processing Record 12 of Set 12 | hirara
# Processing Record 13 of Set 12 | adana
# Processing Record 14 of Set 12 | petersburg
# Processing Record 15 of Set 12 | sainte-suzanne
# Processing Record 16 of Set 12 | mao
# Processing Record 17 of Set 12 | urcos
# Processing Record 18 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 12 | kirakira
# Processing Record 20 of Set 12 | severomorsk
# Processing Record 21 of Set 12 | qaqortoq
# Processing Record 22 of Set 12 | kodino
# Processing Record 23 of Set 12 | ion corvin
# Processing Record 24 of Set 12 | krasnoselkup
# Processing Record 25 of Set 12 | samarai
# Processing Record 26 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 12 | aksarka
# Processing Record 28 of Set 12 | srandakan
# Processing Record 29 of Set 12 | salto del guaira
# Processing Record 30 of Set 12 | kerewan
# Processing Record 31 of Set 12 | chernyshevskiy
# Processing Record 32 of Set 12 | bourail
# Processing Record 33 of Set 12 | iskateley
# Processing Record 34 of Set 12 | praia da vitoria
# Processing Record 35 of Set 12 | naples
# Processing Record 36 of Set 12 | canto do buriti
# Processing Record 37 of Set 12 | olinda
# Processing Record 38 of Set 12 | weyburn
# Processing Record 39 of Set 12 | clarence town
# Processing Record 40 of Set 12 | sabha
# Processing Record 41 of Set 12 | kununurra
# Processing Record 42 of Set 12 | cabrobo
# Processing Record 43 of Set 12 | morbegno
# Processing Record 44 of Set 12 | ixtapa
# Processing Record 45 of Set 12 | ketchikan
# Processing Record 46 of Set 12 | agadez
# Processing Record 47 of Set 12 | loiza
# Processing Record 48 of Set 12 | aguas vermelhas
# Processing Record 49 of Set 12 | stornoway
# Processing Record 50 of Set 12 | biu
# Processing Record 1 of Set 13 | tuy hoa
# Processing Record 2 of Set 13 | santa cruz do sul
# Processing Record 3 of Set 13 | rosarito
# Processing Record 4 of Set 13 | basco
# Processing Record 5 of Set 13 | bollnas
# Processing Record 6 of Set 13 | lagunas
# Processing Record 7 of Set 13 | kuloy
# Processing Record 8 of Set 13 | singaraja
# Processing Record 9 of Set 13 | weligama
# Processing Record 10 of Set 13 | lufilufi
# Processing Record 11 of Set 13 | shellbrook
# Processing Record 12 of Set 13 | shahr-e babak
# Processing Record 13 of Set 13 | paamiut
# Processing Record 14 of Set 13 | itarema
# Processing Record 15 of Set 13 | leogane
# Processing Record 16 of Set 13 | roald
# Processing Record 17 of Set 13 | tevriz
# Processing Record 18 of Set 13 | san rafael
# Processing Record 19 of Set 13 | rajur
# Processing Record 20 of Set 13 | tottori
# Processing Record 21 of Set 13 | ancud
# Processing Record 22 of Set 13 | gonaives
# Processing Record 23 of Set 13 | moorhead
# Processing Record 24 of Set 13 | albanel
# Processing Record 25 of Set 13 | zabol
# Processing Record 26 of Set 13 | sligo
# Processing Record 27 of Set 13 | doha
# Processing Record 28 of Set 13 | albemarle
# Processing Record 29 of Set 13 | nemuro
# Processing Record 30 of Set 13 | gornoye loo
# Processing Record 31 of Set 13 | safaga
# Processing Record 32 of Set 13 | kirov
# Processing Record 33 of Set 13 | arinos
# Processing Record 34 of Set 13 | brownwood
# Processing Record 35 of Set 13 | zyryanka
# Processing Record 36 of Set 13 | alyangula
# Processing Record 37 of Set 13 | suntar
# Processing Record 38 of Set 13 | autazes
# Processing Record 39 of Set 13 | malaya serdoba
# Processing Record 40 of Set 13 | ravar
# Processing Record 41 of Set 13 | bonthe
# Processing Record 42 of Set 13 | saint anthony
# Processing Record 43 of Set 13 | salumbar
# Processing Record 44 of Set 13 | basse
# Processing Record 45 of Set 13 | umm kaddadah
# Processing Record 46 of Set 13 | charters towers
# Processing Record 47 of Set 13 | muzhi
# Processing Record 48 of Set 13 | aden
# Processing Record 49 of Set 13 | sioux lookout
# Processing Record 50 of Set 13 | yokadouma
# Processing Record 1 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 14 | ngunguru
# Processing Record 3 of Set 14 | malaga
# Processing Record 4 of Set 14 | verkhoshizhemye
# Processing Record 5 of Set 14 | solnechnyy
# Processing Record 6 of Set 14 | geraldton
# Processing Record 7 of Set 14 | tlyarota
# City not found. Skipping...
# Processing Record 8 of Set 14 | puranpur
# Processing Record 9 of Set 14 | mandal
# Processing Record 10 of Set 14 | barao de melgaco
# Processing Record 11 of Set 14 | churu
# Processing Record 12 of Set 14 | mahina
# Processing Record 13 of Set 14 | cockburn town
# Processing Record 14 of Set 14 | kota belud
# Processing Record 15 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 14 | rapid valley
# Processing Record 17 of Set 14 | takoradi
# Processing Record 18 of Set 14 | hambantota
# Processing Record 19 of Set 14 | superior
# Processing Record 20 of Set 14 | belgrade
# Processing Record 21 of Set 14 | hvide sande
# Processing Record 22 of Set 14 | kokoda
# Processing Record 23 of Set 14 | alice town
# Processing Record 24 of Set 14 | awjilah
# Processing Record 25 of Set 14 | mount pleasant
# Processing Record 26 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 27 of Set 14 | christchurch
# Processing Record 28 of Set 14 | knysna
# Processing Record 29 of Set 14 | kenosha
# Processing Record 30 of Set 14 | brigham city
# Processing Record 31 of Set 14 | bontang
# Processing Record 32 of Set 14 | yuzhno-kurilsk
# Processing Record 33 of Set 14 | puerto colombia
# Processing Record 34 of Set 14 | santa cruz
# Processing Record 35 of Set 14 | marzuq
# Processing Record 36 of Set 14 | kalmunai
# Processing Record 37 of Set 14 | karia
# Processing Record 38 of Set 14 | jiazi
# Processing Record 39 of Set 14 | macamic
# Processing Record 40 of Set 14 | pipri
# Processing Record 41 of Set 14 | bilibino
# Processing Record 42 of Set 14 | tomatlan
# Processing Record 43 of Set 14 | the valley
# Processing Record 44 of Set 14 | yarkovo
# Processing Record 45 of Set 14 | kapit
# Processing Record 46 of Set 14 | oksfjord
# Processing Record 47 of Set 14 | dehloran
# Processing Record 48 of Set 14 | pucallpa
# Processing Record 49 of Set 14 | chatrapur
# Processing Record 50 of Set 14 | atka
# City not found. Skipping...
# Processing Record 1 of Set 15 | san cristobal
# Processing Record 2 of Set 15 | marataizes
# Processing Record 3 of Set 15 | mezen
# Processing Record 4 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 5 of Set 15 | berlevag
# Processing Record 6 of Set 15 | kalengwa
# Processing Record 7 of Set 15 | celestun
# Processing Record 8 of Set 15 | caluquembe
# Processing Record 9 of Set 15 | vila
# Processing Record 10 of Set 15 | chingirlau
# Processing Record 11 of Set 15 | dubai
# Processing Record 12 of Set 15 | grootfontein
# Processing Record 13 of Set 15 | kharian
# Processing Record 14 of Set 15 | coromandel
# Processing Record 15 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 15 | gobabis
# Processing Record 17 of Set 15 | kudahuvadhoo
# Processing Record 18 of Set 15 | paragominas
# Processing Record 19 of Set 15 | ternate
# Processing Record 20 of Set 15 | arman
# Processing Record 21 of Set 15 | kuliyapitiya
# Processing Record 22 of Set 15 | lucea
# Processing Record 23 of Set 15 | yenagoa
# Processing Record 24 of Set 15 | damnagar
# Processing Record 25 of Set 15 | mariental
# Processing Record 26 of Set 15 | lazaro cardenas
# Processing Record 27 of Set 15 | shar
# Processing Record 28 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 29 of Set 15 | matto
# City not found. Skipping...
# Processing Record 30 of Set 15 | emerald
# Processing Record 31 of Set 15 | pedro leopoldo
# Processing Record 32 of Set 15 | bucerias
# Processing Record 33 of Set 15 | mackay
# Processing Record 34 of Set 15 | furstenfeldbruck
# City not found. Skipping...
# Processing Record 35 of Set 15 | labuan
# Processing Record 36 of Set 15 | bereda
# Processing Record 37 of Set 15 | barguzin
# Processing Record 38 of Set 15 | haverfordwest
# Processing Record 39 of Set 15 | amarante do maranhao
# Processing Record 40 of Set 15 | topeka
# Processing Record 41 of Set 15 | tabas
# Processing Record 42 of Set 15 | gweru
# Processing Record 43 of Set 15 | nizwa
# Processing Record 44 of Set 15 | kuytun
# Processing Record 45 of Set 15 | ibra
# Processing Record 46 of Set 15 | pecos
# Processing Record 47 of Set 15 | diego de almagro
# Processing Record 48 of Set 15 | taltal
# Processing Record 49 of Set 15 | lockhart
# Processing Record 50 of Set 15 | barra patuca
# Processing Record 1 of Set 16 | kailua
# Processing Record 2 of Set 16 | neiafu
# Processing Record 3 of Set 16 | pimentel
# Processing Record 4 of Set 16 | daru
# Processing Record 5 of Set 16 | bismarck
# Processing Record 6 of Set 16 | ingham
# Processing Record 7 of Set 16 | vandra
# Processing Record 8 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 16 | henderson
# Processing Record 10 of Set 16 | storsteinnes
# Processing Record 11 of Set 16 | port moresby
# Processing Record 12 of Set 16 | lithakia
# Processing Record 13 of Set 16 | mandalgovi
# Processing Record 14 of Set 16 | honningsvag
# Processing Record 15 of Set 16 | praia
# Processing Record 16 of Set 16 | ghanzi
# Processing Record 17 of Set 16 | lamesa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     71.06        75          53
# 1            Bluff      NZ -46.6000  168.3333     56.80        78         100
# 2            Alofi      NU -19.0595 -169.9187     79.83        77          43
# 3          Mataura      NZ -46.1927  168.8643     64.13        53         100
# 4       Sao Filipe      CV  14.8961  -24.4956     78.89        79         100
# 5     Constitucion      CL -35.3333  -72.4167     59.43        79          27
# 6            Hobyo      SO   5.3505   48.5268     78.80        70           8
# 7   Port Elizabeth      ZA -33.9180   25.5701     65.10        79          96
# 8     Mamallapuram      IN  12.6264   80.1722     77.05        85          49
# 9     Oktyabrskoye      RU  43.0645   44.7417     32.14       100          99
#
#    Wind Speed Current Description
# 0       14.18       broken clouds
# 1        6.64          light rain
# 2       14.54    scattered clouds
# 3        3.38       moderate rain
# 4        5.01     overcast clouds
# 5       11.07    scattered clouds
# 6       10.63           clear sky
# 7       16.04     overcast clouds
# 8        5.21    scattered clouds
# 9        4.47                mist

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
